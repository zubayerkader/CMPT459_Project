# %%
import pandas as pd
import matplotlib
import scipy.stats
import numpy as np
import re

# %%
cases_train = pd.read_csv('../data/cases_train.csv')
cases_test = pd.read_csv('../data/cases_test.csv')
location = pd.read_csv('../data/location.csv')

print(cases_train)
# print(cases_test)
print(location)
# Out:
#           age     sex           province    country   latitude   longitude  \
# 0         NaN     NaN              Delhi      India  28.614740   77.209100
# 1         NaN     NaN      Uttar Pradesh      India  25.436090   81.847180
# 2         NaN     NaN        Maharashtra      India  18.504220   73.853020
# 3       15-34  female  Baden-Wurttemberg    Germany  48.120860    7.849500
# 4         NaN     NaN            Gujarat      India  23.188409   73.647122
# ...       ...     ...                ...        ...        ...         ...
# 367631   15.0    male           Santa Fe  Argentina -32.967800  -60.659240
# 367632    NaN     NaN              Delhi      India  28.614740   77.209100
# 367633    NaN     NaN        Maharashtra      India  19.200000   72.966670
# 367634     28  female                NaN  Singapore   1.280224  103.834500
# 367635    1.0  female            Sullana       Peru  -4.907630  -80.697330
#
# ...

# %%
age = cases_train.age

nan_count = age.isna().sum()

age = pd.DataFrame(age)

age = age.head(10000) # comment this line for final

for index, r in age.iterrows():
    row = r[0]
#     print(r)
    if r.isnull().values.any():
#         print(row)
        pass
    elif re.match('[0-9][0-9]-[0-9][0-9]', row) or re.match('[0-9]-[0-9][0-9]', row) or re.match('[0-9]-[0-9]', row) or re.match('[0-9][0-9] - [0-9][0-9]', row): # '54-56'
        val = str(row).split('-')
        avg = (int(val[0])+int(val[1]))/2
        age.loc[index] = int(avg)
    elif re.match('[0-9] month', row): # '8 month'
        age.loc[index] = int(int((row[0]+row[1]))/12)
    elif re.match('[0-9][0-9][-|+]$', row): # '80+', '80-'
        age.loc[index] = int(row[0]+row[1])
    else: # converts floats to ints for all other cases
        age.loc[index] = int(float(row))

new_age_col_unimputed = age.copy()

age = age.dropna()

age
# Out:
#      age
# 3     24
# 7     47
# 10    24
# 16    60
# 18    73
# ...   ..
# 9985  64
# 9988  57
# 9994  32
# 9996  47
# 9998  32
#
# [4244 rows x 1 columns]

# %%
nan_count
# Out:
# 209265

# %%
# todo:
# convert age to numeric column and plot histogram
# impute new_age_col_unimputed
# use the imputed column


# age = age.astype('int32')
age.dtypes
# a.hist(figsize=(20,10), bins=10)

#.describe()

#.hist(figsize=(20,10), bins=10)
# scipy.stats.iqr(age)
# Out:
# age    object
# dtype: object
